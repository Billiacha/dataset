# %%
# Findings
print("\nFindings:")
print("1. The dataset has no missing values.")
print("2. Most patients are aged 40–60 years.")
print("3. Patients with heart disease tend to have higher max heart rates.")
print("4. Cholesterol levels vary widely, but very high cholesterol can be linked to heart disease.")
print("5. Scatter plot shows patterns in cholesterol vs. max heart rate across target groups.")
# Out:
# Findings:
# 1. The dataset has no missing values.
# 2. Most patients are aged 40–60 years.
# 3. Patients with heart disease tend to have higher max heart rates.
# 4. Cholesterol levels vary widely, but very high cholesterol can be linked to heart disease.
# 5. Scatter plot shows patterns in cholesterol vs. max heart rate across target groups.

# %%
# Visualization 4: Scatter plot - cholesterol vs max heart rate
plt.figure(figsize=(8,5))
sns.scatterplot(x="chol", y="thalach", hue="target", data=df, palette="Set1")
plt.title("Scatter Plot: Cholesterol vs Max Heart Rate")
plt.xlabel("Cholesterol (mg/dl)")
plt.ylabel("Max Heart Rate (thalach)")
plt.legend(title="Target")
plt.show()

# %%
# Visualization 3: Histogram - age distribution
plt.figure(figsize=(8,5))
plt.hist(df["age"], bins=15, edgecolor="black")
plt.title("Histogram: Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# Visualization 2: Bar chart - average max heart rate per target group
plt.figure(figsize=(8,5))
sns.barplot(x="target", y="thalach", data=df, ci=None, palette="Set2")
plt.title("Bar Chart: Average Max Heart Rate by Target Group")
plt.xlabel("Target (0=No Heart Disease, 1=Heart Disease)")
plt.ylabel("Average Max Heart Rate")
plt.show()
# Out:
# C:\Users\Billiacha\AppData\Local\Temp\ipykernel_45900\239933690.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="target", y="thalach", data=df, ci=None, palette="Set2")
# C:\Users\Billiacha\AppData\Local\Temp\ipykernel_45900\239933690.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="target", y="thalach", data=df, ci=None, palette="Set2")

# %%
# Visualization 1: Line chart - cholesterol trend
plt.figure(figsize=(8,5))
plt.plot(df["chol"], label="Cholesterol")
plt.title("Line Chart: Cholesterol Trend by Patient Index")
plt.xlabel("Patient Index")
plt.ylabel("Cholesterol (mg/dl)")
plt.legend()
plt.show()

# %%
# Group by target
print("\nMean values grouped by target (0=No Heart Disease, 1=Heart Disease):")
print(df.groupby("target").mean())
# Out:
# Mean values grouped by target (0=No Heart Disease, 1=Heart Disease):
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
# Basic statistics
print("\nBasic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Missing values check
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Dataset info
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %%
# Display first rows
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\Billiacha\\Downloads\\heart.csv")

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
